# %% [markdown]
# # TELECOM Bill EDA and Visualization

# %% [markdown]
# # Import Standard Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading data

# %%
df=pd.read_csv("Downloads/telecom_users.csv")

# %% [markdown]
# # Analysing the data

# %%
df.head()
# Out:
#    Unnamed: 0  customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0        1869  7010-BRBUU    Male              0     Yes        Yes      72
# 1        4528  9688-YGXVR  Female              0      No         No      44
# 2        6344  9286-DOJGF  Female              1     Yes         No      38
# 3        6739  6994-KERXL    Male              0      No         No       4
# 4         432  2181-UAESM    Male              0      No         No       2
#
#   PhoneService MultipleLines InternetService  ...     DeviceProtection  \
# 0          Yes           Yes              No  ...  No internet service
# 1          Yes            No     Fiber optic  ...                  Yes
# 2          Yes           Yes     Fiber optic  ...                   No
# 3          Yes            No             DSL  ...                   No
# 4          Yes            No             DSL  ...                  Yes
#
#            TechSupport          StreamingTV      StreamingMovies  \
# ...

# %%
df=df.drop(["Unnamed: 0","customerID"],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5986 entries, 0 to 5985
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            5986 non-null   object
#  1   SeniorCitizen     5986 non-null   int64
#  2   Partner           5986 non-null   object
#  3   Dependents        5986 non-null   object
#  4   tenure            5986 non-null   int64
#  5   PhoneService      5986 non-null   object
#  6   MultipleLines     5986 non-null   object
#  7   InternetService   5986 non-null   object
#  8   OnlineSecurity    5986 non-null   object
#  9   OnlineBackup      5986 non-null   object
#  10  DeviceProtection  5986 non-null   object
#  11  TechSupport       5986 non-null   object
#  12  StreamingTV       5986 non-null   object
#  13  StreamingMovies   5986 non-null   object
#  14  Contract          5986 non-null   object
#  15  PaperlessBilling  5986 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    5986.000000  5986.000000     5986.000000
# mean        0.161377    32.468760       64.802213
# std         0.367909    24.516391       30.114702
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.650000
# 50%         0.000000    29.000000       70.400000
# 75%         0.000000    56.000000       89.900000
# max         1.000000    72.000000      118.750000

# %%
df.corr()
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges
# SeniorCitizen        1.000000  0.005468        0.219387
# tenure               0.005468  1.000000        0.256983
# MonthlyCharges       0.219387  0.256983        1.000000

# %%
df.head(10)
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0    Male              0     Yes        Yes      72          Yes
# 1  Female              0      No         No      44          Yes
# 2  Female              1     Yes         No      38          Yes
# 3    Male              0      No         No       4          Yes
# 4    Male              0      No         No       2          Yes
# 5  Female              0     Yes         No      70           No
# 6  Female              0      No         No      33          Yes
# 7  Female              0      No         No       1           No
# 8    Male              0      No         No      39           No
# 9    Male              1      No         No      55          Yes
#
#       MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0               Yes              No  No internet service  No internet service
# 1                No     Fiber optic                   No                  Yes
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
sns.pairplot(data=df)
plt.show()

# %%
sns.catplot(x="SeniorCitizen", kind="count", data=df)
plt.show()

# %%
sns.catplot(x="gender", kind="count", data=df)
plt.show()

# %%
sns.catplot(x="PhoneService", kind="count", data=df)
plt.show()

# %%
sns.catplot(x="StreamingTV", kind="count", data=df)
plt.show()

# %%
sns.catplot(x="StreamingMovies", kind="count", data=df)
plt.show()

# %%
sns.catplot(x="Partner", kind="count", data=df)
plt.show()

# %%
sns.catplot(x="PaymentMethod", kind="count", data=df,aspect=2)
plt.show()

# %%
sns.catplot(x="InternetService", kind="count", data=df)
plt.show()

# %% [markdown]
# # Factors That Affect Monthly Bill Of Users

# %%
sns.catplot(x="gender", y="MonthlyCharges",kind="swarm", data=df)
plt.show()

# %% [markdown]
# # Gender Of User Does Not Affect Monthly Bills In A Significant Way

# %%
sns.catplot(x="InternetService", y="MonthlyCharges",kind="swarm", data=df)
plt.show()

# %% [markdown]
# # No Internet Connection Leads To Very Low Monthly Bills

# %%
sns.catplot(x="PhoneService", y="MonthlyCharges",kind="swarm", data=df)
plt.show()

# %% [markdown]
# #  No Phone Service Leads To Low Monthly Bills¶

# %%
sns.catplot(x="StreamingMovies", y="MonthlyCharges",kind="swarm", data=df)
plt.show()

# %% [markdown]
# # Movie Streaming Leads To Higher Monthly Bills
# sns.catplot(x="StreamingTV", y="MonthlyCharges",kind="swarm",

# %%
sns.catplot(x="StreamingTV", y="MonthlyCharges",kind="swarm", data=df)
plt.show()

# %% [markdown]
# #  No Streaming TV Connection Leads To Lower Monthly Bills

# %%
sns.catplot(x="Contract", y="MonthlyCharges",kind="swarm", data=df)
plt.show()

# %%
sns.catplot(x="Contract", y="MonthlyCharges", kind="violin", data=df)
plt.show()

# %%
sns.catplot(x="PaymentMethod", y="MonthlyCharges",kind="swarm", data=df,aspect=2)
plt.show()

# %%
sns.catplot(x="PaymentMethod", y="MonthlyCharges", kind="boxen",
            data=df,aspect=2)
plt.show()

# %% [markdown]
# People Who Pay Using Mailed Checks Tend To Have Lower Monthly Bills<br/>
#  People Who Pay Using Electronic Checks Tend To Have Higher Monthly Bills<br/>
#  People Who Pay Using Bank Transfer And Credit Card Tend To Have Almost Equal Monthly Bills<br/>

# %% [markdown]
# # Effect Of Having A Partner On Monthly Bills

# %%
sns.catplot(x="Partner", y="MonthlyCharges",kind="swarm", data=df)
plt.show()

# %%
sns.catplot(x="Partner", y="MonthlyCharges", kind="boxen",
            data=df,aspect=2)
plt.show()

# %%
sns.catplot(x="Partner", y="MonthlyCharges", kind="boxen",
            data=df,aspect=2,hue="gender")
plt.show()

# %%
sns.catplot(x="Partner", y="MonthlyCharges", hue="gender", kind="bar", data=df)
plt.show()

# %% [markdown]
# Men Tend To Have Significantly Higher Monthly Bills When Having A Partner<br/>
# Women Tend To Have Higher Monthly Bills When Having A Partner, But Not As Higher As Men<br/>

# %% [markdown]
# # Effect Of Having Dependents On Monthly Bills

# %%
sns.catplot(x="Dependents", y="MonthlyCharges", kind="bar", data=df)
plt.show()

# %%
sns.catplot(x="Dependents", y="MonthlyCharges", kind="boxen",
            data=df,aspect=2)
plt.show()

# %% [markdown]
# Users Without Dependents Tend To Have Higher Monthly Bills<br/>

# %% [markdown]
# # Effect Of Tenure On Monthly Bills

# %%
sns.boxplot(data=df,x='tenure',color='red')
plt.show()

# %%
sns.distplot(df['tenure'],color='red')
plt.show()

# %%
sns.distplot(df['MonthlyCharges'],color='red')
plt.show()

# %%
sns.relplot(data=df,y="tenure",x="MonthlyCharges",aspect=3,color='red')
plt.show()

# %%
sns.kdeplot(data=df,y="tenure",x="MonthlyCharges",cmap="Reds",shade=True)
plt.show()

# %%
sns.displot(data=df,y="tenure",x="MonthlyCharges",color='red')
plt.show()

# %% [markdown]
# # Users May Expect A Higher Monthly Bill At The Start Of Their Tenure Although There Is Not Very High Significance Between Tenure And Bill
